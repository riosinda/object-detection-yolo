jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5720.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5737.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5754.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5755.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5756.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5775.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5804.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5810.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5843.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5871.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5876.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_588.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5900.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5902.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5932.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5934.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5957.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_5998.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6002.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6026.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6031.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_605.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6099.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_610.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6105.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_616.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6172.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6211.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_625.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6260.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6261.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6305.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6312.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6354.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6373.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_638.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6405.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6417.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6422.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6502.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6508.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6554.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_6581.jpg: corrupt JPEG restored and saved
# ...
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_7953.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_7959.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_7978.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_7994.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8034.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8035.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8037.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8058.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8066.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8093.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8108.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8136.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_814.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8154.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8200.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_8212.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_836.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_882.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_899.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_919.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_924.jpg: ignoring corrupt image/label: image file is truncated (10 bytes not processed)
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_939.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_950.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_958.jpg: corrupt JPEG restored and saved
# train: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\train\train_969.jpg: corrupt JPEG restored and saved
# train: New cache created: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\labels\train.cache
# val: Fast image access  (ping: 0.60.1 ms, read: 67.929.9 MB/s, size: 844.1 KB)
# val: Scanning C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\labels\val... 588 images, 23 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 611/611 109.2it/s 5.6s0.1s
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_115.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_127.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_166.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_172.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_190.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_2.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_209.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_214.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_292.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_295.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_324.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_332.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_334.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_394.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_413.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_471.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_49.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_525.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_72.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_74.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_82.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_85.jpg: corrupt JPEG restored and saved
# val: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\images\val\val_89.jpg: corrupt JPEG restored and saved
# val: New cache created: C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\data\SKU110K_dataset\labels\val.cache
# Plotting labels to C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\runs\detect\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      2.889      3.898      1.758       4021        640: 1% ──────────── 5/537 0.1it/s 46.8s<1:04:51
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 model = YOLO("yolo11n.pt")
#       4 # Train the model on the COCO8 dataset for 100 epochs
# ----> 5 train_results = model.train(
#       6     data="dataset.yaml",  # Path to dataset configuration file
#       7     epochs=100,  # Number of training epochs
#       8     imgsz=640,  # Image size for training
#       9     device="cpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
#      10 )
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\engine\trainer.py:240, in BaseTrainer.train(self)
#     237         ddp_cleanup(self, str(file))
#     239 else:
# --> 240     self._do_train()
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\engine\trainer.py:424, in BaseTrainer._do_train(self)
#     422     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     423 else:
# --> 424     loss, self.loss_items = self.model(batch)
#     425 self.loss = loss.sum()
#     426 if RANK != -1:
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)    135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:339, in BaseModel.loss(self, batch, preds)
#     337 if preds is None:
#     338     preds = self.forward(batch["img"])
# --> 339 return self.criterion(preds, batch)
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\utils\loss.py:272, in v8DetectionLoss.__call__(self, preds, batch)
#     268 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
#     269 # dfl_conf = pred_distri.view(batch_size, -1, 4, self.reg_max).detach().softmax(-1)
#     270 # dfl_conf = (dfl_conf.amax(-1).mean(-1) + dfl_conf.amax(-1).amin(-1)) / 2
# --> 272 _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#     273     # pred_scores.detach().sigmoid() * 0.8 + dfl_conf.unsqueeze(-1) * 0.2,
#     274     pred_scores.detach().sigmoid(),
#     275     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     276     anchor_points * stride_tensor,
#     277     gt_labels,
#     278     gt_bboxes,
#     279     mask_gt,
#     280 )
#     282 target_scores_sum = max(target_scores.sum(), 1)
#     284 # Cls loss
#     285 # loss[1] = self.varifocal_loss(pred_scores, target_scores, target_labels) / target_scores_sum  # VFL way
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\utils\tal.py:82, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      73     return (
#      74         torch.full_like(pd_scores[..., 0], self.num_classes),
#      75         torch.zeros_like(pd_bboxes),
#    (...)     78         torch.zeros_like(pd_scores[..., 0]),
#      79     )
#      81 try:
# ---> 82     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      83 except torch.cuda.OutOfMemoryError:
#      84     # Move tensors to CPU, compute, then move back to original device
#      85     LOGGER.warning("CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU")
#
# File c:\Users\josei\OneDrive\Documentos\AnyoneAI\object-detection-yolo\.venv\Lib\site-packages\ultralytics\utils\tal.py:122, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#     120 pos_align_metrics = align_metric.amax(dim=-1, keepdim=True)  # b, max_num_obj
#     121 pos_overlaps = (overlaps * mask_pos).amax(dim=-1, keepdim=True)  # b, max_num_obj
# --> 122 norm_align_metric = (align_metric * pos_overlaps / (pos_align_metrics + self.eps)).amax(-2).unsqueeze(-1)
#     123 target_scores = target_scores * norm_align_metric
#     125 return target_labels, target_bboxes, target_scores, fg_mask.bool(), target_gt_idx
#
# KeyboardInterrupt:

# %%
# Evaluate the model's performance on the validation set
metrics = model.val()

# %%
# Perform object detection on an image
results = model("path/to/image.jpg")  # Predict on an image
results[0].show()  # Display results

# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
